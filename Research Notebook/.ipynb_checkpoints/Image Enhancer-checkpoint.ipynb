# %% [markdown]
# ## Importing Libraries

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %% [markdown]
# ## Image Data Ingestion

# %%
# There are two images on which we will work on:
# data_test contains an image with a lot of noise which is best to represent M2GLD Algorithm
data_test="..\\Test Images\\TestImage.jpg"
data_path=".\\Data\\Positive"
img_path_t="00655.jpg"

# %%
def resized_frame(image):
    width=256
    height=256
    dimensions=(width,height)
    return cv.resize(image,dimensions,interpolation=cv.INTER_AREA)

# %%
img=cv.imread(os.path.join(data_test),cv.IMREAD_COLOR)
img=resized_frame(img)
cv.imshow('Raw Image',img)
cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### Standard Image Pre-processing

# %%
def convertToGrayscale(image):
    gray=cv.cvtColor(image,cv.COLOR_BGR2GRAY)
    return gray
gray=convertToGrayscale(img)
cv.imshow('Standard Grayscale Image',gray)
cv.waitKey(0)
# Out:
# -1

# %%
blur=cv.GaussianBlur(gray,(5,5),0)
cv.imshow('Standard Blur Gray Image',img)
cv.waitKey(0)
# Out:
# -1

# %%
#Histogram Pixel Intensities
def Hist(img):
    row,col= img.shape[:2] 
    y = np.zeros(256,dtype='uint8')
    for i in range(0,row): 
        for j in range(0,col):
            y[img[i,j]] += 1
            
    x = np.arange(0,256)
    plt.figure(figsize=(15,8))
    plt.bar(x, y, color='b', width=5, align='center', alpha=0.25)
    plt.xticks(np.arange(0,256,step=10))
    plt.show()
    return y
y=Hist(gray);

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
#Threshold Selection (Manual Selection)
threshold,thresh=cv.threshold(blur,128,255,cv.THRESH_BINARY)
cv.imshow('Standard Binarized Image',thresh)
cv.waitKey(0)
# Out:
# -1

# %%
#Feature Detection and Description using ORB Algorithm
orb = cv.ORB_create(nfeatures=1500)
# Make featured Image
keypoints, descriptors = orb.detectAndCompute(thresh, None)
featuredImg = cv.drawKeypoints(thresh, keypoints, None)
cv.imshow('Featured Detection using ORB',featuredImg)
cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# ## Otsu Thresholding

# %%
gray=cv.cvtColor(img,cv.COLOR_BGR2GRAY)
cv.imshow('Otsu Grayscale Image',gray)
cv.waitKey(0)
# Out:
# -1

# %%
blur=cv.GaussianBlur(gray,(5,5),0)
cv.imshow('Otsu Blurred Image',blur)
cv.waitKey(0)
# Out:
# -1

# %%
# Plotting Histogram for the grayscale Image
def calc_hist(img_enhanced):
    gray_hist=cv.calcHist([img_enhanced],[0],None,[256],[0,256])
    gray_hist=gray_hist.flatten()
    Hist(img_enhanced)
    return gray_hist
gray_hist=calc_hist(blur);

# %%
#Histogram Normalization
def normalize_histogram(histogram):
    total_pixels = np.sum(histogram)  # Calculate the total number of pixels
    normalized_histogram = histogram.astype(float) / total_pixels  # Normalize the histogram
    return normalized_histogram

norm_gray_hist=normalize_histogram(gray_hist)

# %%
# Cumulative sum of all bins
def cum_sum_histogram(norm_gray_hist):
    cum_sum=np.cumsum(norm_gray_hist)
    return cum_sum

cum_sum=cum_sum_histogram(norm_gray_hist)
cum_sum[-1]
# Out:
# 1.0

# %%
#Computing Minimum Threshold value
def compute_minimum_thresh(cum_sum, norm_hist):
    bins = np.arange(256)
    min_fn_values=np.zeros_like(norm_hist)
    optimal_threshold=0
    fn_min=np.inf
    for i in range(len(norm_hist)):
        p1,p2 = np.hsplit(norm_hist,[i]) # probabilities
        q1,q2 = cum_sum[i],cum_sum[255]-cum_sum[i] # cum sum of classes
        
        if q1 < 1.e-6 or q2 < 1.e-6:
            continue
            
        b1,b2 = np.hsplit(bins,[i]) # weights
        
        # finding means and variances
        m1,m2 = np.sum(p1*b1)/q1, np.sum(p2*b2)/q2
        v1,v2 = np.sum(((b1-m1)**2)*p1)/q1,np.sum(((b2-m2)**2)*p2)/q2
        
        # calculates the minimization function
        min_fn_value = v1*q1 + v2*q2
        min_fn_values[i]=  min_fn_value
        
        
        #finding the minimum value
        if min_fn_value<fn_min:
            fn_min=min_fn_value
            optimal_threshold=i
    
    return optimal_threshold
optimal_thresh=compute_minimum_thresh(cum_sum,norm_gray_hist)
optimal_thresh
# Out:
# 153

# %%
def otsu_threshold_image(img_enhanced,optimal_threshold):
    threshold,thresh=cv.threshold(img_enhanced,optimal_threshold,255,cv.THRESH_BINARY_INV)
    return thresh
thresh=otsu_threshold_image(blur,optimal_thresh)
cv.imshow('Otsu Thresholded Image',thresh)
cv.waitKey(0)
# Out:
# -1

# %%
def otsu_thresholding(gray_img):
    blur_img=cv.GaussianBlur(gray_img,(5,5),0)
    hist_otsu=calc_hist(blur_img)
    norm_hist_otsu=normalize_histogram(hist_otsu)
    cum_sum_otsu=cum_sum_histogram(norm_hist_otsu)
    optimal_thresh_otsu=compute_minimum_thresh(cum_sum_otsu, norm_hist_otsu)
    print('Optimal Threshold',optimal_thresh_otsu)
    thresh_img=otsu_threshold_image(blur_img,optimal_thresh_otsu)
    return thresh_img

# %%
orb = cv.ORB_create(nfeatures=1500)

# Make featured Image
keypoints, descriptors = orb.detectAndCompute(thresh, None)
featuredImg = cv.drawKeypoints(thresh, keypoints, None)
cv.imshow('Otsu Feature Detection',featuredImg)
cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# ## M2GLD Algorithm

# %%
img_M2GLD=cv.imread(os.path.join(data_test),cv.IMREAD_COLOR)
img_M2GLD=resized_frame(img_M2GLD)
cv.imshow('Raw Crack Image',img_M2GLD)
cv.waitKey(0)
# Out:
# -1

# %%
gray=cv.cvtColor(img_M2GLD,cv.COLOR_BGR2GRAY)
cv.imshow('M2GLD Grayscale Image',gray)
cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![image.png](attachment:image.png)
#
# This formula for performing the M2GLD Algorithm was taken from a paper published on **Detection of Surface Crack in Building Structures Using Image Processing Technique with an Improved Otsu Method for Image Thresholding**
#
# **Nhat-Duc Hoang**
#
# Institute of Research and Development, Faculty of Civil Engineering, Duy Tan University, 03 Quang Trung,
# Da Nang 550000, Vietnam
#
#
# * The tau parameter and R (adjusting ratio) has been set to 0.5 and 1.1

# %%
#This is a grayscale enhancement method which enhances a grayscale image and divid it into two groups of pixel intensities
def M2GLD_Apply(image,R=1.5,tau=0.5):
    
    row,col=image.shape[:2]
    M2GLD_img=np.zeros((row,col),dtype='uint8')
    min_I=300
    max_I=-1

    for i in range(0,row):        
        for j in range(0,col):
            if image[i,j]<min_I:
                min_I=gray[i,j]
            if image[i,j]>max_I:
                max_I=gray[i,j]
    range_I=max_I-min_I
    print("Minimum Intensity:{} Maximum Intensity:{} tau:{} R factor:{}".format(min_I,max_I,tau,R))
    fn=(min_I+(tau*(range_I)))
    for i in range(0,row):        
        for j in range(0,col):            
                if image[i,j]>fn:
                    M2GLD_img[i,j]=np.minimum(min_I,image[i,j]*R)
                else:
                    M2GLD_img[i,j]=np.maximum(min_I,image[i,j]*(1/R))
    return M2GLD_img
M2GLD_img_1=M2GLD_Apply(gray);
# Out:
# Minimum Intensity:39 Maximum Intensity:201 tau:0.5 R factor:1.5

# %%
Hist(M2GLD_img_1);

# %%
blur_MGLD=cv.GaussianBlur(M2GLD_img_1,(5,5),0)
Hist(blur_MGLD);

# %%
threshold,thresh=cv.threshold(M2GLD_img_1,0,255,cv.THRESH_BINARY_INV+cv.THRESH_OTSU)
print(threshold)
cv.imshow('M2GLD Automatic Otsu',thresh)
cv.waitKey(0)
# Out:
# 57.0
# -1

# %% [markdown]
# ### Contrast Trial

# %%
def contrast(image):
    return cv.equalizeHist(image)

# %%
def apply_clahe(image, clip_limit=4.0, grid_size=(8, 8)):
    # Read the image

    # Create a CLAHE object
    clahe = cv.createCLAHE(clipLimit=clip_limit, tileGridSize=grid_size)

    # Apply CLAHE to the image
    clahe_image = clahe.apply(image)

    return clahe_image

# %% [markdown]
# ### M2GLD & Otsu Thresholding Combined

# %%
def M2GLD_Otsu(user_input_image):
    gray_input=convertToGrayscale(user_input_image)   
    M2GLD_img=M2GLD_Apply(gray_input,R=0.4,tau=0.3)
    otsu_img=otsu_thresholding(M2GLD_img)
    return otsu_img,M2GLD_img

Enhanced_img,M2GLD=M2GLD_Otsu(cv.imread("D:\\Documents\\Projects\\Crack-Enhancer\\Data\\Positive\\00001.jpg"))
cv.imshow('Raw Image',cv.imread("D:\\Documents\\Projects\\Crack-Enhancer\\Data\\Positive\\00001.jpg"))
cv.imshow('M2GLD Image',M2GLD)
cv.imshow('Final Image',Enhanced_img)
cv.waitKey(0)
# Out:
# Minimum Intensity:131 Maximum Intensity:152 tau:0.3 R factor:0.4
# Optimal Threshold 122
# -1

# %% [markdown]
# After performing many experimentations with the value of R (Adjusting Ratio) and tau, This was found that there values
# depend on the set of images. For example, The building crack images have a effective parameter values of 1.1 and 0.5 for R
# tau respectively and likewise for the crack image set provided with this project, the initial parameter values that were
# proposed in the paper, are the most effective in defining a crack.

# %%
from platform import python_version
print(python_version())
# Out:
# 3.9.13

# %%
#Gabor Filter Method
def apply_gabor_filter(image, ksize=35, sigma=3.0, theta=np.pi/1, lambd=10.3, gamma=5):
    """
    Apply Gabor filter for surface crack detection on an image.

    Parameters:
        image_path (str): Path to the input image.
        ksize (int, optional): Size of the filter kernel (odd). Default is 31.
        sigma (float, optional): Standard deviation of the Gaussian envelope. Default is 4.0.
        theta (float, optional): Orientation of the filter (in radians). Default is pi/4.
        lambd (float, optional): Wavelength of the sinusoidal factor. Default is 10.0.
        gamma (float, optional): Spatial aspect ratio (ellipticity of the filter). Default is 0.5.
    """
    # Create Gabor filter
    gabor_kernel = cv.getGaborKernel((ksize, ksize), sigma, theta, lambd, gamma, 0, ktype=cv.CV_32F)

    # Apply Gabor filter to the image
    filtered_image = cv.filter2D(image, cv.CV_8UC3, gabor_kernel)
    return filtered_image

# %%
filter_gray=convertToGrayscale(cv.imread("D:\\Documents\\Projects\\Crack-Enhancer\\Data\\Positive\\00001.jpg"))
filtered_image=apply_gabor_filter(filter_gray)
cv.imshow('1',filter_gray)
cv.imshow('2',filtered_image)
cv.waitKey(0)
# Out:
# -1

# %%
data_path="D:\Documents\Projects\Crack-Enhancer\Data"
save_data_path="D:\Documents\Projects\Crack-Enhancer\Data\Processed_Image_Data"

os.makedirs(save_data_path,exist_ok=True)

folder='Positive'
for image in os.listdir(os.path.join(data_path,folder)):
    img=cv.imread(os.path.join(data_path,folder,image))
    enhanced_img,_=M2GLD_Otsu(img);
    cv.imwrite(os.path.join(save_data_path,image),enhanced_img)
# Out:
# Minimum Intensity:131 Maximum Intensity:152 tau:0.3 R factor:0.4
# Optimal Threshold 122
# Minimum Intensity:154 Maximum Intensity:162 tau:0.3 R factor:0.4
# Optimal Threshold 96
# Minimum Intensity:42 Maximum Intensity:159 tau:0.3 R factor:0.4
# Optimal Threshold 91
# Minimum Intensity:154 Maximum Intensity:158 tau:0.3 R factor:0.4
# Optimal Threshold 150
# Minimum Intensity:142 Maximum Intensity:162 tau:0.3 R factor:0.4
# Optimal Threshold 125
# Minimum Intensity:131 Maximum Intensity:163 tau:0.3 R factor:0.4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20280\2795230914.py in <module>
#       7 for image in os.listdir(os.path.join(data_path,folder)):
#       8     img=cv.imread(os.path.join(data_path,folder,image))
# ----> 9     enhanced_img,_=M2GLD_Otsu(img);
#      10     cv.imwrite(os.path.join(save_data_path,image),enhanced_img)
#
# ~\AppData\Local\Temp\ipykernel_20280\2038855181.py in M2GLD_Otsu(user_input_image)
#       2     gray_input=convertToGrayscale(user_input_image)
#       3     M2GLD_img=M2GLD_Apply(gray_input,R=0.4,tau=0.3)
# ----> 4     otsu_img=otsu_thresholding(M2GLD_img)
#       5     return otsu_img,M2GLD_img
#       6
#
# ~\AppData\Local\Temp\ipykernel_20280\3301392601.py in otsu_thresholding(gray_img)
#       1 def otsu_thresholding(gray_img):
#       2     blur_img=cv.GaussianBlur(gray_img,(5,5),0)
# ----> 3     hist_otsu=calc_hist(blur_img)
#       4     norm_hist_otsu=normalize_histogram(hist_otsu)
#       5     cum_sum_otsu=cum_sum_histogram(norm_hist_otsu)
#
# ~\AppData\Local\Temp\ipykernel_20280\3077615301.py in calc_hist(img_enhanced)
#       3     gray_hist=cv.calcHist([img_enhanced],[0],None,[256],[0,256])
#       4     gray_hist=gray_hist.flatten()
# ----> 5     Hist(img_enhanced)
#       6     return gray_hist
#       7 gray_hist=calc_hist(blur);
#
# ~\AppData\Local\Temp\ipykernel_20280\24458688.py in Hist(img)
#      11     plt.bar(x, y, color='b', width=5, align='center', alpha=0.25)
#      12     plt.xticks(np.arange(0,256,step=10))
# ---> 13     plt.show()
#      14     return y
#      15 y=Hist(gray);
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     444     """
#     445     _warn_if_gui_out_of_main_thread()
# --> 446     return _get_backend_mod().show(*args, **kwargs)
#     447
#     448
#
# ~\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2364                 # force the figure dpi to 72), so we need to set it again here.
#    2365                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366                     result = print_method(
#    2367                         filename,
#    2368                         facecolor=facecolor,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in <lambda>(*args, **kwargs)
#    2230                 "bbox_inches_restore"}
#    2231             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234         else:  # Let third-parties do as they see fit.
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     510
#     511     def print_to_buffer(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     455         *pil_kwargs* and *metadata* are forwarded).
#     456         """
# --> 457         FigureCanvasAgg.draw(self)
#     458         mpl.image.imsave(
#     459             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     398              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399               else nullcontext()):
# --> 400             self.figure.draw(self.renderer)
#     401             # A GUI class may be need to update a window using this draw, so
#     402             # don't forget to call the superclass.
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    3138
#    3139             self.patch.draw(renderer)
# -> 3140             mimage._draw_list_compositing_images(
#    3141                 renderer, self, artists, self.suppressComposite)
#    3142
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer)
#    3062             _draw_rasterized(self.figure, artists_rasterized, renderer)
#    3063
# -> 3064         mimage._draw_list_compositing_images(
#    3065             renderer, self, artists, self.figure.suppressComposite)
#    3066
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in draw(self, renderer)
#     586             return
#     587         path = self.get_path()
# --> 588         transform = self.get_transform()
#     589         tpath = transform.transform_path_non_affine(path)
#     590         affine = transform.get_affine()
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in get_transform(self)
#     262     def get_transform(self):
#     263         """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 264         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     265
#     266     def get_data_transform(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in get_patch_transform(self)
#     754             rotation_point = self.rotation_point
#     755         return transforms.BboxTransformTo(bbox) \
# --> 756                 + transforms.Affine2D() \
#     757                 .translate(-rotation_point[0], -rotation_point[1]) \
#     758                 .scale(1, self._aspect_ratio_correction) \
#
# ~\anaconda3\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1893             # A bit faster than np.identity(3).
#    1894             matrix = IdentityTransform._mtx
# -> 1895         self._mtx = matrix.copy()
#    1896         self._invalid = 0
#    1897
#
# KeyboardInterrupt:

# %%
data_path="D:\Documents\Projects\Crack-Enhancer\Data"
save_data_path="D:\Documents\Projects\Crack-Enhancer\Data\Processed_Image_combined"

os.makedirs(save_data_path,exist_ok=True)

folder='Positive'
for image in os.listdir(os.path.join(data_path,folder)):
    img=cv.imread(os.path.join(data_path,folder,image))
    height, width, _ = img.shape
    combined_width = width * 3
    combined_image = np.zeros((height, combined_width, 3), dtype=np.uint8)
    
    enh_img, _ =M2GLD_Otsu(img)
    m2gld=cv.cvtColor(enh_img, cv.COLOR_GRAY2RGB)
    img_gabor=apply_gabor_filter(img)
    enhanced_img,_=M2GLD_Otsu(img_gabor)
    enhanced_img=cv.cvtColor(enhanced_img, cv.COLOR_GRAY2RGB)
    combined_image[:, :width] = img
    combined_image[:, width:2*width] = m2gld
    combined_image[:, 2*width:] = enhanced_img

    cv.imwrite(os.path.join(save_data_path,image),combined_image)
# Out:
# Minimum Intensity:131 Maximum Intensity:152 tau:0.3 R factor:0.4
# Optimal Threshold 122
# Minimum Intensity:148 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 128
# Minimum Intensity:154 Maximum Intensity:162 tau:0.3 R factor:0.4
# Optimal Threshold 96
# Minimum Intensity:153 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 90
# Minimum Intensity:42 Maximum Intensity:159 tau:0.3 R factor:0.4
# Optimal Threshold 91
# Minimum Intensity:150 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 123
# Minimum Intensity:154 Maximum Intensity:158 tau:0.3 R factor:0.4
# Optimal Threshold 150
# Minimum Intensity:154 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 126
# Minimum Intensity:142 Maximum Intensity:162 tau:0.3 R factor:0.4
# Optimal Threshold 125
# Minimum Intensity:154 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 126
# Minimum Intensity:131 Maximum Intensity:163 tau:0.3 R factor:0.4
# Optimal Threshold 120
# Minimum Intensity:146 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 123
# Minimum Intensity:42 Maximum Intensity:162 tau:0.3 R factor:0.4
# Optimal Threshold 96
# Minimum Intensity:156 Maximum Intensity:154 tau:0.3 R factor:0.4
# C:\Users\shanu\AppData\Local\Temp\ipykernel_20280\676137598.py:15: RuntimeWarning: overflow encountered in scalar subtract
#   range_I=max_I-min_I
# Optimal Threshold 124
# Minimum Intensity:139 Maximum Intensity:157 tau:0.3 R factor:0.4
# Optimal Threshold 127
# Minimum Intensity:157 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 124
# Minimum Intensity:144 Maximum Intensity:163 tau:0.3 R factor:0.4
# Optimal Threshold 126
# Minimum Intensity:151 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 126
# Minimum Intensity:149 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 85
# Minimum Intensity:154 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 127
# Minimum Intensity:148 Maximum Intensity:159 tau:0.3 R factor:0.4
# Optimal Threshold 148
# Minimum Intensity:155 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 135
# Minimum Intensity:131 Maximum Intensity:162 tau:0.3 R factor:0.4
# Optimal Threshold 125
# Minimum Intensity:151 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 127
# Minimum Intensity:46 Maximum Intensity:162 tau:0.3 R factor:0.4
# Optimal Threshold 99
# Minimum Intensity:157 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 122
# Minimum Intensity:144 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 134
# Minimum Intensity:156 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 135
# Minimum Intensity:154 Maximum Intensity:162 tau:0.3 R factor:0.4
# Optimal Threshold 148
# Minimum Intensity:151 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 125
# Minimum Intensity:142 Maximum Intensity:166 tau:0.3 R factor:0.4
# Optimal Threshold 92
# Minimum Intensity:163 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 128
# Minimum Intensity:147 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 85
# Minimum Intensity:161 Maximum Intensity:154 tau:0.3 R factor:0.4
# Optimal Threshold 126
# Minimum Intensity:131 Maximum Intensity:161 tau:0.3 R factor:0.4
